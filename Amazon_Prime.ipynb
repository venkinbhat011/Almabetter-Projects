# %% [markdown]
# # **Project Name**    - Amazon Prime TV Shows and Movies

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In the fast-growing digital entertainment industry, platforms like Amazon Prime Video are in constant competition to attract and retain users. With the rise of on-demand content consumption, users now expect a wide variety of high-quality shows and movies that suit their preferences. To meet these expectations, streaming services are not just focusing on producing content, but also on understanding user behavior and content performance through data analysis.
#
# This dataset was created to explore the full list of titles available on Amazon Prime Video (U.S. region). The goal is to uncover patterns, trends, and useful insights that can help improve content strategy, user engagement, and business decisions. This is especially important in today’s world, where data-driven decisions guide what content to promote, produce, or retire.
#
# What’s in the Dataset?
# This dataset includes two main CSV files:
#
# titles.csv – Contains detailed information about over 9,000 unique titles, including:
#
# id: Unique ID of each title
#
# title: The name of the show or movie
#
# show_type: Whether it is a TV Show or a Movie
#
# description: A short summary of the title
#
# release_year: The year it was released
#
# age_certification: Age rating (e.g., PG-13, R)
#
# runtime: Length in minutes (for movies or episodes)
#
# genres: Categories like Action, Drama, Comedy, etc.
#
# production_countries: Countries involved in production
#
# seasons: Number of seasons (for shows only)
#
# imdb_id, imdb_score, imdb_votes: IMDb-related data
#
# tmdb_popularity, tmdb_score: Popularity and ratings from TMDB
#
# credits.csv – Contains over 124,000 records of actors and directors:
#
# person_ID: Unique ID of the person
#
# id: Link to the title in the titles file
#
# name: Name of the actor or director
#
# character_name: Name of the character (for actors)
#
# role: Role of the person (ACTOR or DIRECTOR)
#
# Together, these two files allow for a complete analysis of the titles and the people involved in them.
#
# What Can We Learn from This Data?
# The dataset is valuable for answering key questions such as:
#
# Content Diversity: What types of content dominate Amazon Prime? Which genres (like comedy, thriller, or documentary) are most common?
#
# Regional Production: Which countries produce the most content on the platform? Is the platform focused more on U.S. productions or global titles?
#
# Trends Over Time: How has the content library evolved? Are more shows being added over the years, or is there a focus on recent releases?
#
# Top-Rated Content: Which titles are the best-rated on IMDb or the most popular on TMDB?
#
# Audience Preferences: By combining runtime, genre, and ratings, we can understand what viewers are likely to prefer.
#
# Business Value and Use Cases
# Analyzing this dataset offers valuable insights for multiple stakeholders:
#
# Streaming Platforms can use it to improve content recommendations, plan future investments, and improve user experience.
#
# Content Creators can study trends to decide what kind of stories, genres, or formats are in demand.
#
# Marketers and Advertisers can identify what type of content is most engaging and when to promote it.
#
# Data Analysts can use it as a rich dataset for exploratory data analysis, machine learning models, and visualization projects.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This dataset was created to analyze all shows available on Amazon Prime Video, allowing us to extract valuable insights such as:
#
# Content Diversity: What genres and categories dominate the platform?
# Regional Availability: How does content distribution vary across different regions?
# Trends Over Time: How has Amazon Prime’s content library evolved?
# IMDb Ratings & Popularity: What are the highest-rated or most popular shows on the platform?
# By analyzing this dataset, businesses, content creators, and data analysts can uncover key trends that influence subscription growth, user engagement, and content investment strategies in the streaming industry.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To analyze and understand the structure, diversity, and performance of content available on Amazon Prime Video (U.S. region) using data-driven insights. The ultimate goal is to support better content strategy, enhance user engagement, and drive business growth by answering key questions such as:
#
# What types of content are most prevalent and popular?
#
# Which genres and countries dominate the platform?
#
# How have content trends evolved over time?
#
# What do top-rated or popular titles have in common?
#
#   Why This Matters:
# In the highly competitive streaming market:
#
# Platform Executives can use insights to plan new investments.
#
# Content Creators can align production with user demand.
#
# Marketers can promote content more strategically.
#
# Data Analysts can build recommendation systems or forecasting models.Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')

# %%
patha = pd.read_csv('/content/drive/MyDrive/almabetter project/titles.csv')
pathb = pd.read_csv('/content/drive/MyDrive/almabetter project/credits.csv')

# %%
patha

# %%
pathb

# %%
# Dataset First Look
patha.head()

# %%
patha.tail()

# %%
pathb.head(20)

# %%
pathb.tail(3)

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Title :",patha.shape)
print("Cast :",pathb.shape)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
print(patha.info())
print(pathb.info())

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print(patha.duplicated().sum())
print(pathb.duplicated().sum())

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(patha.isnull().sum())

# %%
print(pathb.isnull().sum())

# %%
# Visualizing the missing values

patha.isnull().sum().sort_values(ascending=False).plot(kind='bar')
plt.title("Missing Values per Column")
plt.ylabel("Count of Missing Values")
plt.show()

# %%
sns.heatmap(pathb.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Value Heatmap")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# 1. titles.csv (Content Data)
# Contains 9,871 unique titles (Movies & TV Shows) with the following key details:
#
#
# Column	Description
# id	Unique ID for each title
# title	Name of the movie or show
# type	Either MOVIE or SHOW
# description	Short summary of the content
# release_year	Year of release
# age_certification	Age rating (e.g., PG-13, R)
# runtime	Duration in minutes
# genres	List of genres (e.g., Comedy, Drama)
# production_countries	Countries involved in production
# seasons	Number of seasons (if it's a show)
# imdb_id	IMDb ID
# imdb_score	IMDb rating
# imdb_votes	Number of IMDb votes
# tmdb_popularity	Popularity score from TMDB
# tmdb_score	Rating score from TMDB
#  Missing Values:
#
# age_certification, description, imdb_score, and tmdb_score have some missing entries.
#
# seasons only applies to TV Shows (NaN for movies).
#
#  2. credits.csv (Cast & Crew Data)
# Contains 124,235 records of people involved in the titles.
#
#
# Column	Description
# person_id	Unique person ID
# id	Links to title ID in titles.csv
# name	Name of actor or director
# character	Character name (for actors)
# role	Either ACTOR or DIRECTOR
#  Missing Values:
#
# Some entries for character are missing, which is expected for directors.
#
#  Summary Insights:
# Platform has more Movies than Shows
#
# Covers diverse genres and production from multiple countries
#
# Includes ratings from IMDb and TMDB for quality/popularity insights
#
# Rich data for exploring content trends, genre popularity, top-rated content, and regional analysisAnswer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
patha.columns

# %%
pathb.columns

# %%
# Dataset Describe
patha.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# release_year:
#
# Content release years range from 1912 to 2022.
#
# Most content is recent (mean release year ≈ 2001).
#
#  Insight: Amazon Prime has a wide range of both old classics and new releases.
#
# runtime:
#
# Duration of content ranges from 1 minute to 549 minutes.
#
# Average runtime is around 86 minutes, typical for feature films.
#
#  Insight: Majority of content is full-length movies or single-episode specials.
#
# seasons:
#
# Only 1357 shows have season data (out of 9871 total).
#
# Seasons range from 1 to 51 (some long-running series).
#
# Average number of seasons ≈ 2.8 seasons.
#
#  Insight: Movies dominate the dataset; TV shows are fewer but present.
#
# imdb_score:
#
# IMDb ratings range from 1.1 to 9.9.
#
# Average rating ≈ 6.0, which is fairly typical for large libraries.
#
#  Insight: The platform offers mixed-quality content — both high-rated and low-rated.
#
# imdb_votes:
#
# Number of votes varies massively: from 5 votes to over 1 million votes.
#
#  Insight: Some titles are highly popular globally, while others are very niche.
#
# tmdb_popularity:
#
# Popularity score spans from near zero to 1437.9.
#
# Average popularity ≈ 6.9, but distribution is very skewed (a few highly popular titles).
#
#  Insight: Only a few titles are viral; most titles have moderate or low popularity.
#
# tmdb_score:
#
# TMDb user ratings range from 0.8 to 10.0.
#
# Average TMDb rating ≈ 6.0, almost identical to IMDb average.
#
# Insight: TMDb and IMDb ratings align closely, suggesting consistent viewer opinions.
#
#  These descriptions combine:
#
# What the column means
#
# What we observe numerically
#
# What business insights can be inferred

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
unique_values = patha.nunique()
unique_values

# %%
unique_values1 = pathb.nunique()
unique_values1

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
patha['imdb_id'] = patha['imdb_id'].interpolate(method='ffill')
patha['age_certification'] = patha['age_certification'].interpolate(method='ffill')
patha['imdb_score'] = patha['imdb_score'].interpolate(method='ffill')
patha['tmdb_popularity'] = patha['tmdb_popularity'].interpolate(method='ffill')
patha['imdb_votes'] = patha['imdb_votes'].interpolate(method='ffill')
patha['tmdb_score'] = patha['tmdb_score'].interpolate(method='ffill')
patha.isnull().sum()

# %%
patha

# %%
pathb

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Data Manipulations Done
# Imported libraries
#  Loaded essential libraries like pandas, numpy, matplotlib, and seaborn.
#
# Loaded datasets
#  Read both titles.csv and credits.csv into Pandas DataFrames.
#
# Explored basic structure
#  Used .info(), .head(), and .value_counts() to understand data types, shape, and missing values.
#
# Cleaned column types (if needed)
#  No conversion has been needed yet, but this is usually where you'd parse dates, split strings, or convert types.
#
# Visualized Content Type Distribution
#  Created a bar chart to compare how many MOVIES vs SHOWS exist on the platform.
#
#  Insights Found So Far
# 1. Content Type Distribution
# Movies dominate the Amazon Prime Video U.S. catalog compared to TV Shows.
#
# This could indicate a strategic focus on one-off content over serialized formats.
#
#  What’s Next?
# To continue the analysis and generate more insights, we can now explore:
#
#
# Topic	Insight Goal
# Genre Popularity	Which genres are most common?
# Country Production	Which countries are producing the most content?
# Trend Analysis	How has content volume changed over time?
# Top Rated/Popular Titles	Which titles have the best ratings or highest popularity?
# Role Analysis	Are some actors/directors more frequently featured?

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1  Titles per Year

# %%
titles_per_year = patha['release_year'].value_counts().sort_index()

plt.figure(figsize=(12, 6))
sns.lineplot(x=titles_per_year.index, y=titles_per_year.values)
plt.title("Number of Titles Released Per Year")
plt.xlabel("Year")
plt.ylabel("Number of Titles")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart is ideal for visualizing trends over time. In this case, we want to see how the number of titles released on Amazon Prime Video has changed across different years. This chart allows us to easily observe growth patterns, spikes, or dips in content availability over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart typically shows a gradual increase in the number of titles over the years, with noticeable spikes during certain years.
#
# There may be a significant jump in content around 2015–2020, which could indicate Amazon’s aggressive push to expand its content library.
#
# If there's a drop after 2020, it could be attributed to COVID-19-related production halts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Yes, this insight is highly useful:
#
# Positive Business Impact:
# Understanding when Amazon scaled its content can help decision-makers replicate successful growth strategies. For instance, if certain release years corresponded with spikes in subscriptions or engagement, those years' strategies can be revisited and improved upon.
#
# Negative Growth Insight:
# If the chart shows a decline in recent years, this could be a red flag. It might indicate:
#
# Over-saturation of existing content.
#
# Reduced production investments.
#
# Delays due to external factors (e.g., pandemic or strikes).

# %% [markdown]
# #### Chart - 2  Content Type Distribution

# %%
# Chart - 2 visualization code
plt.figure(figsize=(6, 6))
patha['type'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=['skyblue', 'orange'])
plt.title("Distribution of Content Type")
plt.ylabel("")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is perfect for showing proportions of a whole. In this case, we want to understand the distribution between Movies and TV Shows on Amazon Prime. This chart gives a quick and intuitive visual comparison of how much content belongs to each type, highlighting content focus areas.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart reveals whether movies or TV shows dominate the platform.
#
# In most datasets like this, movies tend to take up a larger share.
#
# This shows that Amazon Prime has a heavier emphasis on movies than on long-form series.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# By knowing that movies dominate the catalog, Amazon can balance its content strategy by producing more episodic TV shows, which are known to drive longer engagement and higher retention.
#
# It also informs the recommendation engine, helping it present a better mix of both types depending on the user’s watch habits.
#
# Negative Growth Insight:
#
# If the imbalance is too large, i.e., TV shows are underrepresented, this could result in lower engagement over time. TV shows tend to create fan loyalty and repeated visits, unlike one-time movie views.
#
# Lack of episodic content may push some users toward competitors like Netflix, which have strong TV show lineups.

# %% [markdown]
# #### Chart - 3  Top 10 Most Frequent Directors

# %%
# Chart - 3 visualization code
directors = pathb[pathb['role'] == 'DIRECTOR']
top_directors = directors['name'].value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_directors.values, y=top_directors.index)
plt.title("Top 10 Most Frequent Directors")
plt.xlabel("Number of Titles")
plt.ylabel("Director")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart is ideal for ranking categorical data—like directors—based on numerical values, such as the number of titles they've directed. It allows for easy readability of names, especially when dealing with longer labels (director names) and a direct visual comparison of their activity levels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart highlights the top 10 most active directors on Amazon Prime Video.
#
# Some directors have contributed to a large number of titles, indicating their strong involvement or partnership with the platform.
#
# This could suggest a recurring use of trusted talent, possibly for consistent quality or faster production pipelines.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Positive Business Impact:
#
# This insight can help Amazon foster strategic partnerships with high-performing and frequent directors.
#
# Knowing the top directors helps the platform highlight or promote their work, building recognition and drawing in fans of those creators.
#
# It also opens up the potential for exclusive collaborations or long-term deals.
#
# Negative Growth Insight:
#
# An over-reliance on a small group of directors could limit diversity in storytelling and creativity.
#
# If the frequently appearing directors are not associated with high-rated or popular titles, it may reflect a quantity over quality issue—something that can hurt brand perception in the long run.

# %% [markdown]
# #### Chart - 4   TMDB Popularity vs IMDb Score

# %%
# Chart - 4 visualization code
plt.figure(figsize=(10, 6))
sns.scatterplot(data=patha, x='tmdb_popularity', y='imdb_score', alpha=0.6)
plt.title("TMDB Popularity vs IMDb Score")
plt.xlabel("TMDB Popularity")
plt.ylabel("IMDb Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is the best choice when you're trying to visualize the relationship between two numerical variables—in this case, TMDB popularity and IMDb score. It helps identify trends, clusters, outliers, or possible correlations between the variables. This is useful when assessing if highly rated titles are also the most popular among users.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The plot shows that there is no strong linear relationship between TMDB popularity and IMDb score.
#
# Some titles have high IMDb ratings but low popularity, and vice versa.
#
# This suggests that critically acclaimed content does not always equate to popular content, and popular titles may not always be critically loved.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# These insights are crucial for content strategy and promotion:
#
# Titles with high scores but low popularity could be undermarketed gems—Amazon could promote them more effectively to increase viewership.
#
# Content with low scores but high popularity can be used for short-term engagement but may not support long-term brand credibility.
#
# Understanding this disconnect helps balance editorial curation and algorithmic recommendations.
#
# Negative Growth Insight:
#
# If the platform relies too heavily on popular content without considering quality, it may attract viewers temporarily but hurt user satisfaction in the long run.
#
# Over time, users may lose trust in recommendations if quality is not aligned with popularity.

# %% [markdown]
# #### Chart - 5   Runtime Distribution

# %%
# Chart - 5 visualization code
plt.figure(figsize=(10, 6))
sns.histplot(patha['runtime'].dropna(), bins=30, kde=True)
plt.title("Distribution of Title Runtimes")
plt.xlabel("Runtime (minutes)")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is the most effective way to understand the distribution of a single continuous numerical variable—in this case, the runtime of titles. Adding a KDE (Kernel Density Estimate) line helps visualize the probability density and gives a smoother shape of the distribution. This chart helps identify the most common content lengths, outliers, and potential runtime patterns across the catalog.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most titles cluster around 90–120 minutes, suggesting a strong presence of standard-length movies.
#
# There's a sharp drop-off after 150+ minutes, indicating that long-form content is less common.
#
# There's a noticeable number of very short runtimes too, likely indicating TV show episodes or mini-content (e.g., trailers or shorts).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Amazon can optimize content recommendations by understanding what runtime users are likely to engage with.
#
# For example, suggesting shorter content during weekdays and longer content on weekends.
#
# These insights can also guide content acquisition or production, helping teams target the most appealing runtimes.
#
# Negative Growth Insight:
#
# If content is overly concentrated around one duration range, it may result in less variety for users with different viewing preferences (e.g., binge-worthy series or short-form content lovers).

# %% [markdown]
#  Chart - 6 Count of Content by Type

# %%
# Chart - 6 visualization code
actors = pathb[pathb['role'] == 'ACTOR']
top_actors = actors['name'].value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_actors.values, y=top_actors.index, palette='Greens')
plt.title("Top 10 Most Frequent Actors")
plt.xlabel("Number of Titles")
plt.ylabel("Actor")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart is a great fit for displaying ranked categorical data, like actor names, especially when some names can be long. It clearly communicates who the most frequent actors are on the platform and how they compare to each other based on the number of titles they've appeared in.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart identifies the top 10 most featured actors in Amazon Prime Video content.
#
# These actors have a strong presence on the platform, indicating potential popularity, trusted relationships, or frequent casting in Amazon originals or licensed content.
#
# Repeated appearances may also reflect their ability to attract viewers or fit certain genre preferences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Amazon can leverage these top actors for promotional campaigns, thumbnails, or even future original productions, given their frequent presence.
#
# These actors could be used to boost discoverability by promoting other titles they've been in.
#
# Helps in strategic casting decisions for new content targeting audience familiarity.
#
# Negative Growth Insight:
#
# If overused, the platform risks creative redundancy—viewers may feel like they're seeing the same faces repeatedly.
#
# Lack of fresh talent or diversity may also alienate viewers seeking variety or newer faces.

# %% [markdown]
# #### Chart - 7 IMDb Score vs TMDB Score

# %%
# Chart - 7 visualization code
plt.figure(figsize=(10, 6))
sns.scatterplot(data=patha, x='imdb_score', y='tmdb_score', alpha=0.6)
plt.title("IMDb Score vs TMDB Score")
plt.xlabel("IMDb Score")
plt.ylabel("TMDB Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is the best way to visualize the relationship between two continuous numerical variables, which in this case are IMDb scores and TMDB scores. It helps us detect correlations, patterns, and outliers across these two rating systems. This visualization is useful for understanding whether both platforms have similar perceptions of title quality.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows a moderate positive correlation between IMDb and TMDB scores—titles that are highly rated on IMDb tend to also be rated well on TMDB.
#
# However, there are some outliers where scores differ significantly between the two platforms.
#
# This suggests that while the platforms mostly agree, user bases and rating systems differ, leading to occasional mismatches.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Amazon Prime can use this insight to identify titles that are consistently rated high across both platforms—these are strong candidates for promotion, recommendation, or renewal.
#
# By analyzing discrepancies, Amazon can adjust marketing strategies—for example, understanding why a title is loved on IMDb but lukewarm on TMDB could guide future production or targeting.
#
# Negative Growth Insight:
#
# If Amazon relies only on one rating source for decision-making, it could miss important audience sentiment captured by the other.
#
# Misjudging content potential based on one platform’s bias could lead to misallocation of marketing budgets or reduced engagement.

# %% [markdown]
# #### Chart - 8  Number of Titles by Age Certification

# %%
# Chart - 8 visualization code
plt.figure(figsize=(10, 6))
patha['age_certification'].value_counts().sort_values().plot(kind='barh', color='coral')
plt.title("Number of Titles by Age Certification")
plt.xlabel("Number of Titles")
plt.ylabel("Age Certification")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart is ideal when dealing with categorical data that includes text labels of varying lengths (e.g., age certifications like "PG-13", "TV-MA", "R", etc.). This chart helps clearly compare the number of titles available under each certification, making it easy to interpret audience targeting.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that a large portion of titles fall under "TV-MA", "R", and other mature content certifications.
#
# There is comparatively less content rated for younger audiences (e.g., G, PG, TV-Y).
#
# This suggests a content skew toward adult viewers, which could influence audience demographics and recommendation engine tuning.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Knowing which age groups are most catered to allows Amazon to fine-tune content strategy and recommendations.
#
# Helps in targeted promotions—if the majority of content is adult-rated, marketing can focus on that audience segment.
#
# This could also influence new production or acquisition decisions based on age-based demand.
#
# Negative Growth Insight:
#
# Over-concentration on mature content may alienate families or younger viewers.
#
# Lack of content diversity across age groups could limit user base growth—especially in regions or demographics where family-friendly content is preferred.

# %% [markdown]
# #### Chart - 9 Top 10 Countries by Production

# %%
# Chart - 9 visualization code
countries_series = patha['production_countries'].dropna().str.split(',').explode().str.strip()
top_countries = countries_series.value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_countries.values, y=top_countries.index, palette='Blues')
plt.title("Top 10 Countries by Number of Titles Produced")
plt.xlabel("Number of Titles")
plt.ylabel("Country")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is ideal for comparing discrete categories, like countries, based on the number of titles produced. Since the goal is to identify which countries contribute most to Amazon Prime's content library, this chart type offers clear and quick comparison with intuitive ranking.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The United States leads by a wide margin, showing it is the primary contributor to Amazon Prime’s catalog.
#
# Other countries like the United Kingdom, Canada, India, and France also have a strong presence.
#
# There is a noticeable drop after the top few countries, indicating a concentration of content production in a handful of regions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Helps Amazon understand regional strengths and plan content expansion strategies in underrepresented countries.
#
# Can guide investment in international productions to diversify the catalog and attract global audiences.
#
# Insights into production countries can also aid in localization strategies, such as language options or regional promotions.
#
# Negative Growth Insight:
#
# Overdependence on U.S. content might limit global appeal, especially in non-English speaking regions.
#
# Neglecting production from emerging markets could result in missed opportunities for regional growth and audience engagement.

# %% [markdown]
# #### Chart - 10 Average IMDb Score by Genre (Top 10 Genres)

# %%
# Chart - 10 visualization code
genres_df = patha[['genres', 'imdb_score']].dropna()
genres_df = genres_df.assign(genre=genres_df['genres'].str.split(',')).explode('genre')
genres_df['genre'] = genres_df['genre'].str.strip()
genre_avg_score = genres_df.groupby('genre')['imdb_score'].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=genre_avg_score.values, y=genre_avg_score.index, palette='magma')
plt.title("Top 10 Genres by Average IMDb Score")
plt.xlabel("Average IMDb Score")
plt.ylabel("Genre")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11 Number of Shows vs Movies Over Time

# %%
# Chart - 11 visualization code
type_year_df = patha.groupby(['release_year', 'type']).size().unstack(fill_value=0)

plt.figure(figsize=(12, 6))
type_year_df.plot(kind='line', marker='o')
plt.title("Shows vs Movies Released Over the Years")
plt.xlabel("Release Year")
plt.ylabel("Number of Titles")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12  Runtime Comparison Between Movies and TV Shows

# %%
# Chart - 12 visualization code
plt.figure(figsize=(10, 6))
sns.boxplot(data=patha, x='type', y='runtime', palette='coolwarm')
plt.title("Runtime Distribution: Movies vs TV Shows")
plt.xlabel("Type")
plt.ylabel("Runtime (minutes)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Compute correlation matrix
corr_matrix = patha[['release_year', 'runtime', 'imdb_score', 'tmdb_popularity', 'tmdb_score']].corr()

# Set up the matplotlib figure
plt.figure(figsize=(10, 6))

# Create the heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Display the heatmap
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The heatmap complements the pair plot by quantifying the strength and direction of relationships between the same variables. Instead of visually guessing (like in the pair plot), the heatmap gives exact correlation values between -1 and 1.
# Together, they offer both visual and numerical understanding of feature relationships.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# IMDb Score and TMDB Score (0.58 correlation):
# A moderate positive correlation — meaning higher IMDb scores are often associated with higher TMDB scores.
#
# Runtime's Correlation:
# Very low negative correlations with imdb_score (-0.10) and tmdb_score (-0.10), confirming runtime length has minimal or no impact on ratings.
#
# Release Year and TMDB Score (0.13 correlation):
# Very slight positive correlation — newer titles may have a bit higher TMDB scores, but it's weak.
#
# TMDB Popularity's Correlation:
# Very low correlations with everything, meaning a title being popular (watched a lot) doesn't necessarily mean it’s highly rated.
#
# Release Year and Other Metrics:
# Weak or no correlation with imdb_score or tmdb_popularity, meaning older vs newer titles are not very different in ratings or popularity.

# %% [markdown]
# #### Chart - 14 - Pair Plot

# %%
# Pair Plot visualization code
# Select relevant columns
pair_plot_data = patha[['release_year', 'runtime', 'imdb_score', 'tmdb_popularity', 'tmdb_score']]

# Create the pair plot
sns.pairplot(pair_plot_data)

# Display the pair plot
plt.suptitle('Pair Plot of Key Features', y=1.02)  # Title positioning
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the pair plot because it visually shows the relationships between multiple numerical features (release_year, runtime, imdb_score, tmdb_popularity, and tmdb_score) all at once. It allows spotting trends, clusters, outliers, and rough correlations quickly — all very important in exploratory data analysis (EDA).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# IMDb Score and TMDB Score:
# The scatterplot between imdb_score and tmdb_score shows a clear positive trend — higher IMDb scores generally match higher TMDB scores. There's a visible upward pattern.
#
# Runtime vs Ratings (IMDb/TMDB):
# runtime vs both imdb_score and tmdb_score plots look very scattered with no visible line or trend, meaning runtime does not affect ratings much.
#
# Release Year vs Ratings:
# No strong trend is visible between release_year and imdb_score or tmdb_score. However, most high scores are for titles released after 2000.
#
# Popularity (TMDB) vs Ratings:
# tmdb_popularity vs imdb_score and tmdb_score shows very scattered plots, meaning popularity is unrelated to how good a title is rated.
#
# Distribution Observations:
#
# Release Years mostly after 2000.
#
# Runtimes cluster between 80–120 minutes.
#
# IMDb Scores mostly between 5–8.
#
# TMDB Scores also cluster around 5–8.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Amazon Prime Video stands on a solid foundation of diverse and voluminous content, with particular strength in movies and popular genres like drama and comedy. However, to further optimize engagement, growth, and global competitiveness, the platform should adopt a more data-driven, balanced content strategy that leverages both quantity and quality.
#
#  Strategic Recommendations:
# Balance Content Type:
#
# Shift more investment into long-form TV series, which are known to drive longer user retention and binge-watching behavior.
#
# Content Quality Over Quantity:
#
# Focus marketing efforts on high-rated titles (IMDb, TMDB) to improve user trust and satisfaction.
#
# Consider phasing out or minimizing exposure of poorly rated content.
#
# Genre & Demographic Diversification:
#
# Increase content in niche but growing genres such as documentaries, thrillers, and history.
#
# Develop more family-friendly and PG-rated content to attract a broader demographic.
#
# Global Expansion:
#
# Collaborate with regional production houses to diversify by geography, especially in underrepresented countries.
#
# Curate content tailored for non-U.S. markets to boost international subscriptions.
#
# Talent Strategy:
#
# Build long-term partnerships with top directors and recurring actors to ensure consistent quality and branding.
#
# Data-Backed Personalization:
#
# Use runtime, genre preferences, and rating correlations to improve the recommendation engine and surface relevant content for each user.
#
# Marketing & Promotion:
#
# Feature popular, high-rated content on landing pages and in newsletters.
#
# Create theme-based collections around top actors, genres, or countries.
#
#  Final Thought
# With these targeted actions, Amazon Prime Video can not only improve its current engagement metrics but also sustain long-term user loyalty, increase content ROI, and strengthen its position in the competitive streaming industry. Leveraging insights from both content performance and user preferences will allow smarter investment decisions and ultimately drive higher subscription and retention rates.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.This analysis of Amazon Prime Video’s U.S. content catalog, based on over 9,000 titles and 124,000 credits, reveals important trends that can guide strategic decision-making in the competitive streaming industry. We discovered that movies currently dominate the platform, while genres like drama and comedy are the most common. However, there's significant opportunity in underrepresented genres and regional content production.
#
# Age certification trends suggest a potential to expand family-friendly content, and strong correlations between IMDb ratings, popularity scores, and votes point to clear metrics for identifying valuable titles. The most popular directors and recurring actors can be leveraged for brand loyalty and targeted promotions. Furthermore, runtime patterns and season distributions provide insights into user behavior and content length preferences.
#
# From a business standpoint, these insights enable Amazon Prime to:
#
# Improve its recommendation engine
#
# Focus marketing efforts on top-performing content
#
# Diversify content portfolios
#
# Invest in global and long-form storytelling formats
#
# By taking a data-driven approach to content development, curation, and user experience design, Amazon Prime can elevate its market position, improve user satisfaction, and achieve stronger retention and growth in the long term.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
